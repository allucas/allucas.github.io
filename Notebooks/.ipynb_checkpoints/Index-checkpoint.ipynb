# %%
# %%javascript
# (function(on) {
# const e=$( "<a>Setup failed</a>" );
# const ns="js_jupyter_suppress_warnings";
# var cssrules=$("#"+ns);
# if(!cssrules.length) cssrules = $("<style id='"+ns+"' type='text/css'>div.output_stderr { } </style>").appendTo("head");
# e.click(function() {
#     var s='Showing';
#     cssrules.empty()
#     if(on) {
#         s='';
#         cssrules.append("div.output_stderr, div[data-mime-type*='.stderr'] { display:none; }");
#     }
#     e.text(s+'');
#     on=!on;
# }).click();
# $(element).append(e);
# })(true);

# %% [markdown]
# # COVID-19 Vaccine and Treatment Development Tracker
#
# Welcome to **covid-vaccine-tracker.com**. This website presents a summary of the data published by the **WHO** regarding the develipment of COVID-19 vaccines (https://www.who.int/blueprint/priority-diseases/key-action/novel-coronavirus-landscape-ncov.pdf?ua=1). Data for treatments for COVID-19 under development is derived from the **Milken Institute** vaccine and treatment spreadsheet (https://milkeninstitute.org/sites/default/files/2020-03/Covid19-Tracker-3-36-20-FINAL.pdf). No modifications have been made to the data. This has been done as an attempt to make this information more easily accessible to the public. The website is updated on a daily basis.

# %% [markdown]
# ## COVID-19 Vaccines in Development

# %% [markdown]
# ### COVID-19 Vaccine Platforms in Development

# %%
import pandas as pd

import tabula

import requests

from ggplot import *

import seaborn as sns

import matplotlib.pyplot as plt

import numpy as np

import matplotlib

# Change figure sizes
temp = plt.rcParams['figure.dpi'] = 100

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 12}

matplotlib.rc('font', **font)


#url = 'https://milkeninstitute.org/sites/default/files/2020-03/Covid19-Tracker-3-36-20-FINAL.pdf'

url = 'https://www.who.int/blueprint/priority-diseases/key-action/novel-coronavirus-landscape-ncov.pdf?ua=1'

myfile = requests.get(url)
open('COVID19-data.pdf', 'wb').write(myfile.content)

#declare the path of your file
file_path = "COVID19-data.pdf"
#Convert your file
df = tabula.read_pdf(file_path, pages='all', lattice=True,multiple_tables=False)
#df = df[10]
#df = df.drop(index=0)
df = df[0]
df = df.dropna(axis=0,thresh=5)
# Out:
# Got stderr: Mar 27, 2020 11:51:25 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font BCDGEE+Calibri-Light are not implemented in PDFBox and will be ignored
# Mar 27, 2020 11:51:25 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font BCDIEE+Calibri are not implemented in PDFBox and will be ignored

# %%
#%% Clean the data


df.columns = ['platform', 'type_product', 'developer', 'covid', 'stage',
              'other']

a = df['platform'].values
aa = df['stage'].values
b = []

for i in range(len(a)):
    #aa[i] = aa[i].replace('\r',' ')
    b.append(a[i].replace('\r',' '))
    if b[i] == 'Platform':
        b[i] = np.nan

df['platform'] = b

# Evaluate the different trial types
stages = ['Pre-Clinical', 'Phase 1', 'Phase 2', 'Phase 3']

c = df['stage'].values
stage_list = []

for i in range(len(c)):
    stage = c[i]
    for j in range(len(stages)):
        if stages[j] in stage:
            stage_list.append(stages[j])
    if len(stage_list)<i+1:
            stage_list.append(np.nan)
    

df['stage'] = stage_list


# Change the typer of product
d = df['type_product'].values
b = []

for i in range(len(d)):
    b.append(d[i].replace('\r',' '))
    if b[i] == 'Type of candidate vaccine':
        b[i] = np.nan

df['type_product'] = b

# Change the developer names
d = df['developer'].values
b = []

for i in range(len(d)):
    b.append(d[i].replace('\r',' '))
    if b[i] == 'Developer':
        b[i] = np.nan

df['developer'] = b

# Change the other names
d = df['other'].values
b = []

for i in range(len(d)):
    if str(d[i]) == 'nan':
        b.append(np.nan)
    else:
        b.append(d[i].replace('\r',' '))
    if b[i] == 'Same platform for non-Coronavirus candidates':
        b[i] = np.nan

df['other'] = b

# %%
#%% Plot
#fig=plt.figure(figsize=(25, 10), dpi= 80, facecolor='w', edgecolor='k')
chart = sns.catplot(x="platform", kind="count", palette="ch:.25", data=df);
t = plt.xlabel('Vaccine Platform')
t = plt.ylabel('Count')
t = chart.set_xticklabels(rotation=90)


#chart2 = sns.catplot(x="stage", kind="count", palette="ch:.25", data=df);
#t = plt.xlabel('FDA Phase')
#t = chart2.set_xticklabels(rotation=75)

#%%
#plt.figure()
#plat_count = df['platform'].value_counts()
#chart3 = sns.barplot(plat_count.index, plat_count.values, alpha=0.8,palette="ch:.25")
#plt.setp(chart3.get_xticklabels(), rotation=90)
#plt.xlabel('Vaccine Platform')
#plt.ylabel('Count')
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### Vaccine Clincal Trial Phase

# %%
chart2 = sns.catplot(x="stage", kind="count", palette="ch:.25", data=df);
t = plt.xlabel('Trial Phase')
t = plt.ylabel('Count')
t = chart2.set_xticklabels(rotation=0)

# %% [markdown]
# ### Vaccine Data

# %% [markdown]
# I have filtered the WHO data and made it more accessible. If you would like a spreadsheet version of this data, please email me at: *covid.vaccine.tracker@gmail.com*

# %%
df = df.drop(columns='covid')
df.columns = ['Vaccine Platform', 'Vaccine Specifics', 'Company \n Developer', 'Trial Stage', 'Other Uses']
df = df.dropna(axis=0,thresh=4)

# %%
# Show an interactive dataframe table
import itables.interactive
df
# Out:
#                  Vaccine Platform  \
# 0   Non- Replicating Viral Vector
# 1                             RNA
# 6                             DNA
# 7                             DNA
# 8                             DNA
# 9                     Inactivated
# 10          Live Attenuated Virus
# 11  Non- Replicating Viral Vector
# 12  Non- Replicating Viral Vector
# 13  Non- Replicating Viral Vector
# 14  Non- Replicating Viral Vector
# 15  Non- Replicating Viral Vector
# 16  Non- Replicating Viral Vector
# 17                Protein Subunit
# 18                Protein Subunit
# 19                Protein Subunit
# 20                Protein Subunit
# 21                Protein Subunit
# 22                Protein Subunit
# 23                Protein Subunit
# 24                Protein Subunit
# 25                Protein Subunit
# 26                Protein Subunit
# 27                Protein Subunit
# 28                Protein Subunit
# 29                Protein Subunit
# 30                Protein Subunit
# 31                Protein Subunit
# 32       Replicating Viral Vector
# 33       Replicating Viral Vector
# 34       Replicating Viral Vector
# 35                            RNA
# 36                            RNA
# 37                            RNA
# 38                            RNA
# 39                            RNA
# 40                            RNA
# 41                            RNA
# 42                            VLP
# 43                        Unknown
# 44                        Unknown
# 45                        Unknown
# 46                        Unknown
# 47                        Unknown
#
#                                     Vaccine Specifics  \
# 0                            Adenovirus Type 5 Vector
# 1                              LNP- encapsulated mRNA
# 6          DNA plasmid vaccine Electroporation device
# 7                                                 DNA
# 8                                 DNA plasmid vaccine
# 9                    Formaldehyde- inactivated + alum
# 10               Deoptimized live attanuated vaccines
# 11                                    MVA encoded VLP
# 12                     Ad26 (alone or with MVA boost)
# 13                                            ChAdOx1
# 14  adenovirus- based NasoVAX expressing SARS2-CoV...
# 15                          Ad5 S (GREVAXTM platform)
# 16                              Oral Vaccine platform
# 17   Drosophila S2 insect cell expression system VLPs
# 18                                          S protein
# 19                                           S-Trimer
# 20                                            Peptide
# 21                                          S protein
# 22                                     Ii-Key peptide
# 23                                          S protein
# 24                 S protein (baculovirus production)
# 25     Full length S trimers/ nanoparticle + Matrix M
# 26                                     gp-96 backbone
# 27           Molecular clamp stabilized Spike protein
# 28                                  S1 or RBD protein
# 29                    Subunit protein, plant produced
# 30                                            Subunit
# 31                     Adjuvanted microsphere peptide
# 32                                     Measles Vector
# 33                                     Measles Vector
# 34               Horsepox vector expressing S protein
# 35      LNP- encapsulated mRNA  cocktail encoding VLP
# 36                LNP- encapsulated mRNA encoding RBD
# 37                                               mRNA
# 38                                               mRNA
# 39                                               mRNA
# 40                                              saRNA
# 41                                               mRNA
# 42                                  Plant-derived VLP
# 43                                            Unknown
# 44                                            Unknown
# 45                                            Unknown
# 46                                            Unknown
# 47                                            Unknown
#
#                                  Company \n Developer   Trial Stage  \
# 0   CanSino Biological Inc. and Beijing Institute ...       Phase 1
# 1                                       Moderna/NIAID       Phase 1
# 6                              Inovio Pharmaceuticals  Pre-Clinical
# 7                  Takis/Applied DNA Sciences/Evvivax  Pre-Clinical
# 8                                        Zydus Cadila  Pre-Clinical
# 9                                             Sinovac  Pre-Clinical
# 10                 Codagenix/Serum Institute of India  Pre-Clinical
# 11                                    GeoVax/BravoVax  Pre-Clinical
# 12                   Janssen Pharmaceutical Companies  Pre-Clinical
# 13                               University of Oxford  Pre-Clinical
# 14                                          Altimmune  Pre-Clinical
# 15                                            Greffex  Pre-Clinical
# 16                                             Vaxart  Pre-Clinical
# 17                                         ExpreS2ion  Pre-Clinical
# 18                                     WRAIR/USAMRIID  Pre-Clinical
# 19                 Clover Biopharmaceuticals Inc./GSK  Pre-Clinical
# 20                                          Vaxil Bio  Pre-Clinical
# 21                                        AJ Vaccines  Pre-Clinical
# 22                                     Generex/EpiVax  Pre-Clinical
# 23                            EpiVax/Univ. of Georgia  Pre-Clinical
# 24                                     Sanofi Pasteur  Pre-Clinical
# 25                                            Novavax  Pre-Clinical
# 26                      Heat Biologics/Univ. Of Miami  Pre-Clinical
# 27                       University of Queensland/GSK  Pre-Clinical
# 28                         Baylor College of Medicine  Pre-Clinical
# 29                                   iBio/CC-Pharming  Pre-Clinical
# 30          VIDO-InterVac, University of Saskatchewan  Pre-Clinical
# 31                         University of Saskatchewan  Pre-Clinical
# 32                                       Zydus Cadila  Pre-Clinical
# 33  Institute Pasteur/Themis/Univ. of Pittsburg Ce...  Pre-Clinical
# 34                     Tonix Pharma/Southern Research  Pre-Clinical
# 35  Fudan University/ Shanghai JiaoTong University...  Pre-Clinical
# 36  Fudan University/ Shanghai JiaoTong University...  Pre-Clinical
# 37               China CDC/Tongji University/Stermina  Pre-Clinical
# 38                                  Arcturus/Duke-NUS  Pre-Clinical
# 39                       BioNTech/Fosun Pharma/Pfizer  Pre-Clinical
# 40                            Imperial College London  Pre-Clinical
# 41                                            Curevac  Pre-Clinical
# 42                                      Medicago Inc.  Pre-Clinical
# 43                            University of Hong Kong  Pre-Clinical
# 44                                      ImmunoPrecise  Pre-Clinical
# 45                   MIGAL Galilee Research Institute  Pre-Clinical
# 46                                  Doherty Institute  Pre-Clinical
# 47                                  Tulane University  Pre-Clinical
#
#                                            Other Uses
# 0                                               Ebola
# 1                                 multiple candidates
# 6   Lassa, Nipah HIV Filovirus HPV Cancer indicati...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                SARS
# 10               HAV, InfA, ZIKV, FMD, SIV, RSV, DENV
# 11                              LASV, EBOV, MARV, HIV
# 12                                    Ebola, HIV, RSV
# 13     influenza, TB, Chikungunya, Zika, MenB, plague
# 14                                          influenza
# 15                                               MERS
# 16       InfA, CHIKV, LASV, NORV; EBOV, RVF, HBV, VEE
# 17                                                NaN
# 18                                                NaN
# 19                                 HIV, REV Influenza
# 20                                                NaN
# 21                                                NaN
# 22                          Influenza, HIV, SARS- CoV
# 23                                               H7N9
# 24                                Influenza, SARS-CoV
# 25                          RSV; CCHF, HPV, VZV, EBOV
# 26                          NSCLC, HIV, malaria, Zika
# 27                     Nipah, influenza, Ebola, Lassa
# 28                                               SARS
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                West nile, chik, Ebola, Lassa, Zika
# 34                                Smallpox, monkeypox
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                multiple candidates
# 39                                                NaN
# 40                 EBOV; LASV, MARV, Inf (H7N9), RABV
# 41     RABV, LASV, YFV; MERS, InfA, ZIKV, DengV, NIPV
# 42  Flu, Rotavirus, Norovirus, West Nile virus, Ca...
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN

# %% [markdown]
# ## COVID-19 Treatment Options in Development

# %%
# load the data
url = 'https://milkeninstitute.org/sites/default/files/2020-03/Covid19-Tracker-3-36-20-FINAL.pdf'

#url = 'https://www.who.int/blueprint/priority-diseases/key-action/novel-coronavirus-landscape-ncov.pdf?ua=1'

myfile = requests.get(url)
open('COVID19-data2.pdf', 'wb').write(myfile.content)

#declare the path of your file
file_path = "COVID19-data2.pdf"
#Convert your file
df = tabula.read_pdf(file_path, pages='all', lattice=True,multiple_tables=True)
#df = df[10]
#df = df.drop(index=0)
#df = df[0]
#df = df.dropna(axis=0,thresh=5)



for i in range(len(df)):
    temp_df = df[i]
    if temp_df.shape[1] == 9:
        if 'df_all' in locals():
            df_all = df_all.append(temp_df)
        else:
            df_all = temp_df
        
df_all = df_all.dropna(axis=0, thresh=5)
df_all = df_all.dropna(axis=1, how='all')

# %%
# prepare the data
#%% Remove the control characters
cols = list(df_all.columns)
for i in range(len(cols)):
    list_a = df_all[cols[i]].values
    for j in range(len(list_a)):
        if isinstance(list_a[j], str) and ('\r' in list_a[j]):
            list_a[j] = list_a[j].replace('\r',' ')
        if isinstance(list_a[j], str) and ('*' in list_a[j]):
            list_a[j] = list_a[j].replace('*','')
        
    df_all[cols[i]] = list_a

for i in range(len(cols)):
    if isinstance(cols[i], str) and ('\r' in cols[i]):
        cols[i] = cols[i].replace('\r',' ')
    if isinstance(cols[i], str) and ('*' in cols[i]):
        cols[i] = cols[i].replace('*','')
    
df_all.columns = cols

# %% [markdown]
# ### COVID-19 Treatment Options (Top 5 Pursued Approaches)

# %%
plat_count = df_all['Type of Product - Treatment'].value_counts()
n_plot = 5
chart = sns.barplot(plat_count[:n_plot].index, plat_count[:n_plot].values, alpha=0.8,palette="ch:.25")
plt.setp(chart.get_xticklabels(), rotation=90)
plt.xlabel('Top '+ str(n_plot)+' Treatment Approaches Being Pursued')
plt.ylabel('Count')
chart.spines['top'].set_visible(False)
chart.spines['right'].set_visible(False)

# %% [markdown]
# ### Treatment Trial Phase

# %%
plat_count = df_all['Current Stage of Development'].value_counts()
chart = sns.barplot(plat_count.index, plat_count.values, alpha=0.8,palette="ch:.25")
plt.setp(chart.get_xticklabels(), rotation=45)
plt.xlabel('Stage of Development for All Treatments')
plt.ylabel('Count')
chart.spines['top'].set_visible(False)
chart.spines['right'].set_visible(False)

# %% [markdown]
# ### Treatment Clinical Trial Phases and Months

# %%
#%% Get the dates for the clinical trials

phases = []
dates = []
timing = df_all['Anticipated Next Steps Timing'].values
for i in range(len(timing)):
    if isinstance(timing[i], str) and ('Phase 1' in timing[i]):
        phases.append('Phase 1')
    elif isinstance(timing[i], str) and ('Phase 2' in timing[i]):
        phases.append('Phase 2')
    else:
        phases.append(np.nan)


months = ['January','February', 'March', 'April', 'May', 'June', 'July', 'August',
          'September', 'October', 'November', 'December']
for i in range(len(timing)):
    for j in range(len(months)):
        if isinstance(timing[i], str) and (months[j] in timing[i]):
            dates.append(months[j])
    if len(dates)<i+1:
        dates.append(np.nan)

df_all2 = df_all.copy()
df_all2['dates'] = dates
df_all2['phases'] = phases

# %%
#%%

plat_count = df_all2['phases'].value_counts()
chart = sns.barplot(plat_count.index, plat_count.values, alpha=0.8,palette="ch:.25")
plt.setp(chart.get_xticklabels(), rotation=45)
plt.xlabel('Phases of Clinical Trials')
plt.ylabel('Count')
chart.spines['top'].set_visible(False)
chart.spines['right'].set_visible(False)  

#%%
plt.figure()
plat_count = df_all2['dates'].value_counts()
chart = sns.barplot(plat_count.index, plat_count.values, alpha=0.8,palette="ch:.25", order=months)
plt.setp(chart.get_xticklabels(), rotation=45)
plt.xlabel('Months of Clinical Trials')
plt.ylabel('Count')
chart.spines['top'].set_visible(False)
chart.spines['right'].set_visible(False)

# %% [markdown]
# ### Treatment Data

# %%
df_all
# Out:
#    Number                        Type of Product - Treatment  \
# 1       1        TAK-888, antibodies from recovered COVID-19
# 3       2  Antibodies from mice, REGN3048-3051, against t...
# 4       3        Antibodies from recovered COVID-19 patients
# 5       4        Antibodies from recovered COVID-19 patients
# 6       5        Antibodies from recovered COVID-19 patients
# ..    ...                                                ...
# 0      72  nafamostat, approved in Japan to treat pancrea...
# 1      73  A number of synthesized nanoviricide drug cand...
# 2      74                                           losartan
# 3      75  Activase (alteplase), tissue plasminogen activ...
# 5       1                  Washed microbiota transplantation
#
#    FDA-Approved Indications  \
# 1                       N/A
# 3                       N/A
# 4                       N/A
# 5                       N/A
# 6                       N/A
# ..                      ...
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 5                       NaN
#
#                                  Developer/Researcher  \
# 1                                              Takeda
# 3                                           Regeneron
# 4                                           Celltrion
# 5                                              Kamada
# 6                   Vir Biotech/WuXi Biologics/Biogen
# ..                                                ...
# 0   University of Tokyo/ National Center for Globa...
# 1                                       NanoViricides
# 2                             University of Minnesota
# 3   Beth Israel Deaconess, the University of Color...
# 5   The Second Hospital of Nanjing Medical University
#
#    Current Stage of Development  \
# 1                  Pre-clinical
# 3                  Pre-clinical
# 4                  Pre-clinical
# 5                  Pre-clinical
# 6                  Pre-clinical
# ..                          ...
# 0                  Pre-clinical
# 1                  Pre-clinical
# 2                      Clinical
# 3             Compassionate Use
# 5                      Clinical
#
#                                       Funding Sources  \
# 1                                                 NaN
# 3   Biomedical Advanced Research and Development A...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# ..                                                ...
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 5                                                 NaN
#
#                         Anticipated Next Steps Timing  \
# 1   To patients between September 2020 and Septemb...
# 3                             Start Phase 1 June 2020
# 4                        Start Phase 1 September 2020
# 5                                                 NaN
# 6                           Start Phase 1 ~ July 2020
# ..                                                ...
# 0                             Trial starts April 2020
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 5                    Primary trial ends April 2, 2020
#
#                                               Sources  \
# 1                           PhRMA Wall Street Journal
# 3   Stat News MarketWatch Reuters Bloomberg News F...
# 4                                        Korea Herald
# 5                                     BioSpace AbbVie
# 6                               Stat News Vir Biotech
# ..                                                ...
# 0                                      Bloomberg News
# 1            Clinical Trials Arena NanoViricides Inc.
# 2                          ClinicalTrials.gov KARE TV
# 3                                            MIT News
# 5                                                 NaN
#
#                 FDA-Approved Indications (Treatments)  \
# 1                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# ..                                                ...
# 0                                                 N/A
# 1                                                 N/A
# 2   FDA-approved since 1995, approved to treat hyp...
# 3   FDA-approved since 1987, approved to treat str...
# 5                                             Unknown
#
#    Clinical Trials Ongoing for Other Diseases Developer/ Researcher
# 1                                         NaN                   NaN
# 3                                         NaN                   NaN
# 4                                         NaN                   NaN
# 5                                         NaN                   NaN
# 6                                         NaN                   NaN
# ..                                        ...                   ...
# 0                                         NaN                   NaN
# 1                                         NaN                   NaN
# 2                                         NaN                   NaN
# 3                                         NaN                   NaN
# 5                                         NaN                   NaN
#
# [76 rows x 11 columns]

# %% [markdown]
# ### Citation
#
# Lucas, A. COVID-19 Vaccine Development Tracker. 27 Mar. 2020, covid-vaccine-tracker.com. DOI:10.5281/zenodo.3731761
